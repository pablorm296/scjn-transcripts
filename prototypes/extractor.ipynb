# %%
import requests

# %%
ENDPOINT_URL = "https://bj.scjn.gob.mx/api/versiones-taquigraficas/versionesTaq/asuntos"
PARAMS = {
    "page": 1,
    "size": 10
}

# %%
response = requests.get(ENDPOINT_URL, params = PARAMS)
print(response.status_code)
print(response.json())
# Out:
# 200
# ...
